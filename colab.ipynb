# %% [markdown]
# Importing Functions

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")
df
# Out:
#      Student Id  Number of Logins  Number of Content Reads  Interaction  \
# 0           100                45                       25          105
# 1           101                55                       28           70
# 2           102                36                       49          141
# 3           103                49                       35           98
# 4           104                28                       34          124
# ..          ...               ...                      ...          ...
# 400         500                56                       28          146
# 401         501                41                       45           76
# 402         502                43                       34           55
# 403         503                51                       57          171
# 404         504                68                       51          139
#
#      Number of Forum Reads  Number of Forum Posts  Number of Quiz Reviews  \
# ...

# %%
# Out:
# <Axes: >
